# %%
import pandas as pd
i
train = pd.read_excel('data/mara.xlsx')
train.head()
# Out:
#          name             addr
# 0      손오공마라탕  (지번) 동교동 169-14
# 1  손오공마라탕 서교점  (지번) 서교동 369-26
# 2        희래식당  (지번) 역삼동 825-20
# 3  중경마라탕 강남역점  (지번) 역삼동 619-17
# 4         진지아   (지번) 송파동 23-10

# %%
trainset = train['addr']
trainset
# Out:
# 0      (지번) 동교동 169-14
# 1      (지번) 서교동 369-26
# 2      (지번) 역삼동 825-20
# 3      (지번) 역삼동 619-17
# 4       (지번) 송파동 23-10
#             ...
# 295     (지번) 구로동 794-3
# 296       (지번) 군자동 361
# 297        (지번) 구로동 97
# 298    (지번) 구로동 130-32
# 299       (지번) 인사동 263
# Name: addr, Length: 300, dtype: object

# %%
for i in range(300):
    test = trainset[i].split()[1]
    print(test)
# Out:
# 동교동
# 서교동
# 역삼동
# 역삼동
# 송파동
# 역삼동
# 을지로2가
# 동선동1가
# 서교동
# 대림동
# 자양동
# 창천동
# 창천동
# 명동2가
# 역삼동
# 서초동
# 남대문로1가
# 회기동
# 역삼동
# 신림동
# 송파동
# 창천동
# 혜화동
# 자양동
# 반포동
# 동교동
# 서교동
# 태평로1가
# 하왕십리동
# 서교동
# 봉천동
# 명륜2가
# 대현동
# 입정동
# 낙성대동
# 종로5가
# 서교동
# 역삼동
# 역삼동
# 역삼동
# 대치동
# 상암동
# 도화동
# 영등포동
# 남현동
# 신문로1가
# 연남동
# 구로동
# 등촌동
# 장안동
# 자양동
# 신길동
# 성내동
# 신사동
# 회현동1가
# 삼성동
# 동교동
# 대현동
# 동교동
# 봉천동
# 노량진동
# 역삼동
# 신림동
# 회현동1가
# 제기동
# 봉천동
# 구로동
# 당산동6가
# 수유동
# 신림동
# 문래동3가
# 구로동
# 서교동
# 회기동
# 대치동
# 노량진동
# 역삼동
# 신림동
# 회현동1가
# 제기동
# 봉천동
# 구로동
# 당산동6가
# 수유동
# 신림동
# 문래동3가
# 구로동
# 서교동
# 회기동
# 대치동
# 서초동
# 을지로6가
# 화곡6동
# 청담동
# 상암동
# 잠실동
# 한남동
# 역삼동
# 마곡동
# 자양동
# 여의도동
# 이문동
# 회기동
# 청진동
# 중계동
# 신림동
# 자양동
# 흑석동
# 공릉동
# 중화동
# 대림동
# 안암동5가
# 화양동
# 여의도동
# 서초동
# 신림동
# 가락동
# 자양동
# 신천동
# 신당동
# 대림동
# 명륜2가
# 명동2가
# 서교동
# 서교동
# 안암동5가
# 사당동
# 역삼동
# 잠원동
# 행당동
# 북창동
# 이문동
# 창천동
# 사당동
# 충정로1가
# 관철동
# 수유동
# 갈현동
# 서교동
# 월계동
# 중림동
# 논현동
# 망원동
# 서교동
# 상암동
# 태평로2가
# 잠실동
# 가양동
# 흑석동
# 여의도동
# 관철동
# 수유동
# 갈현동
# 서교동
# 월계동
# 중림동
# 논현동
# 망원동
# ...

# %%
test = trainset[0].split()
test
# Out:
# ['(지번)', '동교동', '169-14']

# %%
shee
